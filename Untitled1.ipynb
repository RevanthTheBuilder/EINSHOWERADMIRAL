# %% [markdown]
# <a href="https://colab.research.google.com/github/EINSHOWERADMIRAL/EINSHOWERADMIRAL/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
 #Step 1:  import library
import pandas as pd

# %%
#step 2: import dataset
salary = pd.read_csv('https://github.com/YBI-Foundation/Dataset/raw/refs/heads/main/Salary%20Data.csv')

# %%
salary.head()
# Out:
#    Experience Years  Salary
# 0               1.1   39343
# 1               1.2   42774
# 2               1.3   46205
# 3               1.5   37731
# 4               2.0   43525

# %%
salary.shape
# Out:
# (40, 2)

# %%
salary.shape
# Out:
# (40, 2)

# %%
X.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-bc5f1a0adac8> in <cell line: 1>()
# ----> 1 X.shape
#
# NameError: name 'X' is not defined

# %%
# step 3: define target (Y) and features (U)

# %%
salary.columns
# Out:
# Index(['Experience Years', 'Salary'], dtype='object')

# %%
Y = salary['Salary']

# %%
U = salary[['Experience Years']]

# %%
U.shape
# Out:
# (40, 1)

# %%
Y.shape
# Out:
# (40,)

# %%
salary.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40 entries, 0 to 39
# Data columns (total 2 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Experience Years  40 non-null     float64
#  1   Salary            40 non-null     int64
# dtypes: float64(1), int64(1)
# memory usage: 768.0 bytes

# %%
salary.describe()
# Out:
#        Experience Years         Salary
# count         40.000000      40.000000
# mean           5.152500   74743.625000
# std            2.663715   25947.122885
# min            1.100000   37731.000000
# 25%            3.200000   56878.250000
# 50%            4.600000   64472.500000
# 75%            6.875000   95023.250000
# max           10.500000  122391.000000

# %%
#Step no 4: train test split the dataset for building the accurate model.

# %%
from sklearn.model_selection import train_test_split

# %%
#U_train, U_test, Y_train, Y_test = train_test_split(U,Y)
U_train, U_test, Y_train, Y_test = train_test_split(U,Y, train_size=0.6, random_state=10000)
U_train
#U_train, U_test, Y_train, Y_test = train_test_split(U,Y, test_size=0.5)
# Out:
#     Experience Years
# 27               6.2
# 10               3.2
# 9                3.2
# 26               6.0
# 32               8.2
# 28               6.5
# 15               4.0
# 14               3.9
# 39              10.5
# 19               4.5
# 11               3.5
# 37               9.6
# 7                2.9
# 22               5.1
# 33               8.5
# 36               9.5
# 35               9.0
# 6                2.5
# 17               4.1
# 8                3.0
# 21               4.9
# 2                1.3
# 31               7.9
# 12               3.7

# %%
U_train.shape, U_test.shape, Y_train.shape, Y_test.shape
# Out:
# ((24, 1), (16, 1), (24,), (16,))
